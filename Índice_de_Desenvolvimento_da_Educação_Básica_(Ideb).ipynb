# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavolenin/Indice-de-Desenvolvimento-da-Educacao-Basica-Ideb-/blob/main/%C3%8Dndice_de_Desenvolvimento_da_Educa%C3%A7%C3%A3o_B%C3%A1sica_(Ideb).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install basedosdados

# %%
import basedosdados as bd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.core.display import HTML
from IPython.display import Image

def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'ggplot')
    plt.rcParams['figure.figsize'] = [24, 9]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %%
df_regiao = bd.read_table(dataset_id='br_inep_ideb',table_id='regiao',billing_project_id='projeto-365519')
# Out:
# Downloading: 100%|██████████| 495/495 [00:00<00:00, 983.05rows/s]

# %%
df_regiao.head()
# Out:
#     ano        regiao      rede       ensino  anos_escolares  taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 0  2005  Centro-Oeste  estadual  fundamental    finais (6-9)            72.1              0.721828                233.50                       227.88                     4.356453   3.1       NaN
# 1  2005  Centro-Oeste  estadual  fundamental  iniciais (1-5)            83.0              0.837081                185.38                       172.13                     4.631618   3.9       NaN
# 2  2005  Centro-Oeste  estadual        medio     todos (1-4)            68.0              0.695138                261.23                       251.52                     4.123654   2.9       NaN
# 3  2005  Centro-Oeste   privada  fundamental    finais (6-9)            94.4              0.943491                283.57                       266.82                     5.840183   5.5       NaN
# ...

# %%
df_brasil = bd.read_table(dataset_id='br_inep_ideb',table_id='brasil',billing_project_id='projeto-365519')
# Out:
# Downloading: 100%|██████████| 126/126 [00:00<00:00, 498.79rows/s]

# %%
df_brasil.head()
# Out:
#     ano       rede       ensino  anos_escolares  taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 0  2005   estadual  fundamental    finais (6-9)            76.3              0.763635                232.86                       226.60                     4.324370   3.3       NaN
# 1  2005   estadual  fundamental  iniciais (1-5)            85.5              0.863753                181.13                       172.19                     4.551878   3.9       NaN
# 2  2005   estadual        medio     todos (1-4)            70.5              0.747708                260.02                       248.69                     4.064599   3.0       NaN
# 3  2005  municipal  fundamental    finais (6-9)            73.2              0.740564                228.44                       222.53                     4.182879   3.1       NaN
# ...

# %%
df_uf = bd.read_table(dataset_id='br_inep_ideb',table_id='uf',billing_project_id='projeto-365519')
# Out:
# Downloading: 100%|██████████| 2673/2673 [00:00<00:00, 3627.35rows/s]

# %%
df_uf.head()
# Out:
#     ano sigla_uf      rede       ensino  anos_escolares  taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 0  2005       AC  estadual  fundamental    finais (6-9)            82.9              0.834163                224.91                       227.27                     4.202988   3.5       NaN
# 1  2005       AC  estadual  fundamental  iniciais (1-5)            78.4              0.789825                169.19                       166.80                     4.229711   3.3       NaN
# 2  2005       AC  estadual        medio     todos (1-4)            72.7              0.770317                249.88                       245.24                     3.870503   3.0       NaN
# 3  2005       AC   privada  fundamental    finais (6-9)            95.9              0.958336                256.67                       257.54                     5.236878   5.0       NaN
# ...

# %%
# Verificando os DataFrames resultantes
df_regiao.tail()
# Out:
#       ano regiao     rede       ensino  anos_escolares  taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 490  2021    Sul  publica  fundamental    finais (6-9)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       5.6
# 491  2021    Sul  publica  fundamental  iniciais (1-5)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       6.4
# 492  2021    Sul    total  fundamental    finais (6-9)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       5.8
# 493  2021    Sul    total  fundamental  iniciais (1-5)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       6.5
# ...

# %%
df_brasil.tail()
# Out:
#       ano     rede       ensino  anos_escolares  taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 121  2021  publica  fundamental  iniciais (1-5)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       5.8
# 122  2021  publica        medio     todos (1-4)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       4.9
# 123  2021    total  fundamental    finais (6-9)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       5.5
# 124  2021    total  fundamental  iniciais (1-5)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       6.0
# ...

# %%
df_uf.tail()
# Out:
#        ano sigla_uf     rede       ensino  anos_escolares  taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 2668  2021       TO  publica  fundamental    finais (6-9)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       5.3
# 2669  2021       TO  publica  fundamental  iniciais (1-5)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       5.7
# 2670  2021       TO    total  fundamental    finais (6-9)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       5.4
# 2671  2021       TO    total  fundamental  iniciais (1-5)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       5.7
# ...

# %% [markdown]
# # Entendimento das Variáveis

# %% [markdown]
# ## Dataframe df_regiao
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Dataframe df_brasil
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Dataframe df_uf
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Dimensões dos datasets

# %%
# df_regiao
print("DataFrame df_regiao:")
print(f"Numero de Linhas: {df_regiao.shape[0]}")
print(f"Numero de Colunas: {df_regiao.shape[1]}")
print(f"Shape: {df_regiao.shape}")
# Out:
# DataFrame df_regiao:
# Numero de Linhas: 495
# Numero de Colunas: 12
# Shape: (495, 12)

# %%
# df_brasil
print("DataFrame df_brasil:")
print(f"Numero de Linhas: {df_brasil.shape[0]}")
print(f"Numero de Colunas: {df_brasil.shape[1]}")
print(f"Shape: {df_brasil.shape}")
# Out:
# DataFrame df_brasil:
# Numero de Linhas: 126
# Numero de Colunas: 11
# Shape: (126, 11)

# %%
# df_uf
print("DataFrame df_uf:")
print(f"Numero de Linhas: {df_uf.shape[0]}")
print(f"Numero de Colunas: {df_uf.shape[1]}")
print(f"Shape: {df_uf.shape}")
# Out:
# DataFrame df_uf:
# Numero de Linhas: 2673
# Numero de Colunas: 12
# Shape: (2673, 12)

# %% [markdown]
# ## Verificação de tipos de variáveis

# %%
# df_regiao
print(df_regiao.dtypes)
# Out:
# ano                              Int64
# regiao                          object
# rede                            object
# ensino                          object
# anos_escolares                  object
# taxa_aprovacao                 float64
# indicador_rendimento           float64
# nota_saeb_matematica           float64
# nota_saeb_lingua_portuguesa    float64
# nota_saeb_media_padronizada    float64
# ideb                           float64
# projecao                       float64
# dtype: object

# %%
# df_brasil
print(df_regiao.dtypes)
# Out:
# ano                              Int64
# regiao                          object
# rede                            object
# ensino                          object
# anos_escolares                  object
# taxa_aprovacao                 float64
# indicador_rendimento           float64
# nota_saeb_matematica           float64
# nota_saeb_lingua_portuguesa    float64
# nota_saeb_media_padronizada    float64
# ideb                           float64
# projecao                       float64
# dtype: object

# %%
# df_uf
print(df_uf.dtypes)
# Out:
# ano                              Int64
# sigla_uf                        object
# rede                            object
# ensino                          object
# anos_escolares                  object
# taxa_aprovacao                 float64
# indicador_rendimento           float64
# nota_saeb_matematica           float64
# nota_saeb_lingua_portuguesa    float64
# nota_saeb_media_padronizada    float64
# ideb                           float64
# projecao                       float64
# dtype: object

# %% [markdown]
# As variáveis apresentam os tipos adequados.

# %% [markdown]
# ## Limpeza do Dataset

# %% [markdown]
# ### Checar Valores Faltantes, nulos ou NA

# %%
# df_regiao
print(df_regiao.isnull().sum())
# Out:
# ano                             0
# regiao                          0
# rede                            0
# ensino                          0
# anos_escolares                  0
# taxa_aprovacao                 55
# indicador_rendimento           55
# nota_saeb_matematica           55
# nota_saeb_lingua_portuguesa    55
# nota_saeb_media_padronizada    55
# ideb                           55
# projecao                       55
# dtype: int64

# %%
# df_brasil
print(df_brasil.isnull().sum())
# Out:
# ano                             0
# rede                            0
# ensino                          0
# anos_escolares                  0
# taxa_aprovacao                 14
# indicador_rendimento           14
# nota_saeb_matematica           14
# nota_saeb_lingua_portuguesa    14
# nota_saeb_media_padronizada    14
# ideb                           14
# projecao                       14
# dtype: int64

# %%
# df_uf
print(df_uf.isnull().sum())
# Out:
# ano                              0
# sigla_uf                         0
# rede                             0
# ensino                           0
# anos_escolares                   0
# taxa_aprovacao                 297
# indicador_rendimento           297
# nota_saeb_matematica           320
# nota_saeb_lingua_portuguesa    320
# nota_saeb_media_padronizada    320
# ideb                           320
# projecao                       297
# dtype: int64

# %%
df_regiao[df_regiao['ano'] == 2021].head()
# Out:
#       ano        regiao      rede       ensino  anos_escolares  taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 440  2021  Centro-Oeste  estadual  fundamental    finais (6-9)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       5.2
# 441  2021  Centro-Oeste  estadual  fundamental  iniciais (1-5)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       6.1
# 442  2021  Centro-Oeste  estadual        medio     todos (1-4)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       4.7
# 443  2021  Centro-Oeste   privada  fundamental    finais (6-9)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       7.1
# ...

# %%
df_brasil[df_brasil['ano'] == 2021].head()
# Out:
#       ano       rede       ensino  anos_escolares  taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 112  2021   estadual  fundamental    finais (6-9)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       5.3
# 113  2021   estadual  fundamental  iniciais (1-5)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       6.1
# 114  2021   estadual        medio     todos (1-4)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       4.9
# 115  2021  municipal  fundamental    finais (6-9)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       5.1
# ...

# %%
df_uf[df_uf['ano']==2021].head()
# Out:
#        ano sigla_uf      rede       ensino  anos_escolares  taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 2376  2021       AC  estadual  fundamental    finais (6-9)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       5.5
# 2377  2021       AC  estadual  fundamental  iniciais (1-5)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       5.6
# 2378  2021       AC  estadual        medio     todos (1-4)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       4.8
# 2379  2021       AC   privada  fundamental    finais (6-9)             NaN                   NaN                   NaN                          NaN                          NaN   NaN       6.8
# ...

# %% [markdown]
# Conforme percebemos nos dataframes, os dados referentes ao ano de 2021 são NaN, em virtude do objetivo desta análise (acompanhar a evolução do IDEB ao longo dos anos) não desejamos trabalhar com projeções, portanto, descartaremos os dados referentes a este ano.

# %%
# Dropando as linhas referentes ao ano 2021
df_regiao = df_regiao[df_regiao['ano']!=2021]
df_brasil = df_brasil[df_brasil['ano']!=2021]
df_uf = df_uf[df_uf['ano']!=2021]

# %%
# Verificação do shape após a eliminação dos dados
df_regiao.shape
# Out:
# (440, 12)

# %%
df_brasil.shape
# Out:
# (112, 11)

# %%
df_uf.shape
# Out:
# (2376, 12)

# %% [markdown]
# ## Análise do Dataset

# %% [markdown]
# ### Estatística Descritiva

# %%
num_variables_regiao = df_regiao.select_dtypes(include=['int64', 'float64'])
cat_variables_regiao = df_regiao.select_dtypes(exclude=['int64', 'float64'])

num_variables_brasil = df_brasil.select_dtypes(include=['int64', 'float64'])
cat_variables_brasil = df_brasil.select_dtypes(exclude=['int64', 'float64'])

num_variables_uf = df_uf.select_dtypes(include=['int64', 'float64'])
cat_variables_uf = df_uf.select_dtypes(exclude=['int64', 'float64'])

# %%
# Aplicado ao DataFrame df_regiao
df_regiao_describe = df_regiao.describe().T
df_regiao_skewness  = pd.DataFrame(num_variables_regiao.skew(),columns=['skew'])
df_regiao_kurtosis  = pd.DataFrame(num_variables_regiao.kurtosis(),columns=['kurtosis'])
df_regiao_median    = pd.DataFrame(num_variables_regiao.median(),columns=['median'])
df_regiao_intervalo = pd.DataFrame(num_variables_regiao.max() - num_variables_regiao.min(),columns=['range'])
df_descritive_statistics = pd.concat([df_regiao_describe,df_regiao_skewness,df_regiao_kurtosis,df_regiao_median,df_regiao_intervalo],axis=1)
df_descritive_statistics
# Out:
#                              count         mean        std          min          25%          50%          75%          max      skew  kurtosis       median       range
# ano                          440.0  2012.000000   4.587792  2005.000000  2008.500000  2012.000000  2015.500000  2019.000000  0.000000 -1.238519  2012.000000   14.000000
# taxa_aprovacao               440.0    87.037273   8.622951    66.800000    80.400000    88.700000    94.625000    99.400000 -0.439165 -0.998529    88.700000   32.600000
# indicador_rendimento         440.0     0.877072   0.078779     0.668975     0.812951     0.887899     0.948105     0.994000 -0.372409 -1.000117     0.887899    0.325025
# nota_saeb_matematica         440.0   250.111386  38.741761   156.410000   225.560000   248.965000   273.397500   346.420000  0.260733 -0.122395   248.965000  190.010000
# ...

# %%
# Aplicado ao DataFrame df_brasil
df_brasil_describe = df_brasil.describe().T
df_brasil_skewness  = pd.DataFrame(num_variables_brasil.skew(),columns=['skew'])
df_brasil_kurtosis  = pd.DataFrame(num_variables_brasil.kurtosis(),columns=['kurtosis'])
df_brasil_median    = pd.DataFrame(num_variables_brasil.median(),columns=['median'])
df_brasil_intervalo = pd.DataFrame(num_variables_brasil.max() - num_variables_brasil.min(),columns=['range'])
df_descritive_statistics = pd.concat([df_brasil_describe,df_brasil_skewness,df_brasil_kurtosis,df_brasil_median,df_brasil_intervalo],axis=1)
df_descritive_statistics
# Out:
#                              count         mean        std          min          25%          50%          75%          max      skew  kurtosis       median       range
# ano                          112.0  2012.000000   4.603172  2005.000000  2008.500000  2012.000000  2015.500000  2019.000000  0.000000 -1.239652  2012.000000   14.000000
# taxa_aprovacao               112.0    86.414286   7.813984    70.500000    80.075000    85.950000    93.800000    98.800000 -0.211732 -1.095884    85.950000   28.300000
# indicador_rendimento         112.0     0.871692   0.069868     0.740564     0.816136     0.864541     0.939767     0.988399 -0.046465 -1.261783     0.864541    0.247835
# nota_saeb_matematica         112.0   248.639464  35.903213   174.860000   224.047500   249.135000   265.397500   334.720000  0.363603  0.132906   249.135000  159.860000
# ...

# %%
# DataFrame df_regiao
# Verificar os valores únicos em cada variável categórica
cat_variables_regiao.apply(lambda x: x.unique())
# Out:
# regiao            [Centro-Oeste, Nordeste, Norte, Sudeste, Sul]
# rede                        [estadual, privada, publica, total]
# ensino                                     [fundamental, medio]
# anos_escolares      [finais (6-9), iniciais (1-5), todos (1-4)]
# dtype: object

# %%
# DataFrame df_brasil
# Verificar os valores únicos em cada variável categórica
cat_variables_brasil.apply(lambda x: x.unique())
# Out:
# rede              [estadual, municipal, privada, publica, total]
# ensino                                      [fundamental, medio]
# anos_escolares       [finais (6-9), iniciais (1-5), todos (1-4)]
# dtype: object

# %% [markdown]
# ## Correlação (duas variáveis)

# %%
corr_brasil = df_brasil.corr()
sns.heatmap(corr_brasil,xticklabels=corr_brasil.columns,yticklabels=corr_brasil.columns,annot=True,cmap=sns.diverging_palette(220,20, as_cmap=True));

# %% [markdown]
# Se observarmos a variável `ideb` podemos identificar uma alta correlação com as seguintes variáveis: `taxa_aprovacao`, `indicador_rendimento`, `nota_saeb_media_padronizada` e `projecao`. Dessa forma, interpretamos que altos valores de `indicador_rendimento` são acompanhados por altos valores destas variáveis: `taxa_aprovacao`, `indicador_rendimento`, `nota_saeb_media_padronizada` e `projecao`. Isso pois as correlações entre a variável `ideb` e as demais variáveis mencionadas são positivas.
#
# O coeficiente de correlação de Pearson avalia o grau e a direção da correlação linear entre duas variáveis. Deste modo, quanto mais próximos de 1 ou -1, maior a intensidade da correlação, o sinal indica apenas a direção (positivamente correlacionados ou negativamente correlacionados). Deve-se mencionar também que quanto mais próximo de 0 menor a força da correlação.

# %% [markdown]
# ## Scatterplots

# %% [markdown]
# Nessa seção, criaremos gráficos de dispersão para analisarmos o comportamento destes gráficos bivariados em busca de identificar possíveis padrões. As imagens aparesentadas representam os dados referentes ao país (df_brasil).

# %%
# Create the function to visualize to bar chart
def draw_scatterplot(list_feature,df):
    fig, ax = plt.subplots(int(len(list_feature)/2),2, figsize=(15,15))
    colunas = list_feature
    indice = 0
    for j in range(len(ax)):
        for i in range(len(ax[j])):
            ax[j][i].tick_params(labelsize=12)
            ax[j][i] = sns.scatterplot(data=df, x=colunas[indice],y='ideb',ax=ax[j][i])
            indice += 1
    fig.suptitle('Gráficos de Dispersão - IDEB em função de outras variáveis', position=(.5,1), fontsize=22)
    fig.tight_layout(pad=5)
    return
list_features_regiao = num_variables_regiao.columns.drop(['ideb','ano'])
list_features_brasil = num_variables_brasil.columns.drop(['ideb','ano'])

# %%
# df_regiao 
draw_scatterplot(list_features_brasil,df_brasil)

# %% [markdown]
# Percebemos claramente a tendência de aumento no IDEB à medida que são aumentadas as variáveis: `taxa_aprovacao`, `indicador_rendimento`, `nota_saeb_media_padronizada` e `projecao`.

# %% [markdown]
# ## Histogramas

# %%
def draw_histplot(num_variables):
    fig, ax = plt.subplots(int(len(num_variables.columns)/2),2, figsize=(15,15))
    colunas = num_variables.columns
    indice = 0
    for j in range(len(ax)):
        for i in range(len(ax[j])):
            ax[j][i].tick_params(labelsize=12)
            ax[j][i] = sns.histplot(data=num_variables[colunas[indice]],ax=ax[j][i])
            indice += 1
    fig.suptitle('Histogramas', position=(.5,1), fontsize=22)
    fig.tight_layout(pad=5)
    return

# %%
draw_histplot(num_variables_brasil)

# %% [markdown]
# A avaliação do IDEB ocorre a cada dois anos, através do histograma podemos ratificar isto. Alguns dos insights que extraímos a partir da interpretação dos gráficos:
# * A variável taxa de aprovação possuiu maior frequência de distribuição dos dados para valores próximos a 95;
# * O indicador de rendimento apresentou a maior quantidade de dados em valores próximos a 0,95;
# * A maioria das notas saeb de matemática e de língua portuguesa estiveram próximas a 250;
# * A nota saeb média padronizada com maior frequência esteve por volta de 4,75;
# * O valor de IDEB mais frequente esteve por volta de 3,75;
# * A variável projeção apresentou a maioria dos valores em torno de 4,50.

# %% [markdown]
# ## KDE plots

# %% [markdown]
# O KDEplot é uma forma mais suavizada de exibir os dados em comparação com o histograma. Através desse tipo de gráfico também podemos analisar a distribuição das variáveis.

# %%
# Função que auxilia na plotagem dos gráficos KDE
def plot_kde(num_attributes):
    num_attributes.ano = num_attributes.ano.astype('int')
    fig, ax = plt.subplots(int(len(num_attributes.columns)),1, figsize=(12,30))
    colunas = num_attributes.columns
    indice = 0
    for j in range(len(ax)):
      ax[j].tick_params(labelsize=10)
      ax[j] = sns.kdeplot(data=num_attributes[colunas[indice]], ax=ax[j],shade=True)
      indice += 1
    fig.suptitle('KDE Plots', position=(.5,1), fontsize=20)
    fig.tight_layout(pad=5)
    return
# KDE plot 
plot_kde(num_variables_brasil)

# %% [markdown]
# As interpretações provenientes da análise dos KDEplots foram semelhantes às obtidas através dos histogramas.

# %% [markdown]
# ## Boxplot

# %% [markdown]
# O boxplot, ou gráfico de caixa, é um gráfico que permite a identificação de outliers bem como visualizar os quartis. Nesta seção, utilizaremos o dataset contendo informações a respeito das regiões (df_regiao) visando realizar comparações acerca das distribuições.

# %%
# Função que auxilia na plotagem dos gráficos Boxplot
def plot_boxplot(num_attributes):
    num_attributes.ano = num_attributes.ano.astype('int')
    fig, ax = plt.subplots(int(len(num_attributes.columns)/2),2, figsize=(20,20))
    colunas = num_attributes.columns
    indice = 0
    for j in range(len(ax)):
        for i in range(len(ax[j])):
            ax[j][i].tick_params(labelsize=12)
            ax[j][i].tick_params(labelsize=10)
            ax[j][i] = sns.boxplot(data=num_attributes, ax=ax[j][i], x=df_regiao['regiao'], y=num_attributes[colunas[indice]])
            indice += 1
    fig.suptitle('Boxplots', position=(.5,1), fontsize=20)
    fig.tight_layout(pad=5)
    return
# Boxplot
plot_boxplot(num_variables_regiao)

# %% [markdown]
# Notamos que apenas a variável `nota_saeb_matemática` possui outlier. Além disso, podemos chegar às seguintes conclusões:
# * A maior e a menor taxa de aprovação e indicador de rendimento no país foram referentes, respectivamente, às regiões Sudeste e Nordeste;
# * O maior e menor indicador de rendimento foi respectivamente Sudeste e Nordeste;
# * As regiõs Sul e Sudeste se destacaram positivamente em relação às notas saeb de matemática e português, portanto também se destacaram nas médias padronizadas das notas saeb. A região Nordeste apresentou os piores valores para cada uma destas 3 variáveis.
# * A região com menor IDEB e menor projeção foi o Nordeste, enquanto o Sudeste foi a região com maior IDEB e maior projeção.

# %% [markdown]
# ## IDEB por Região, Rede de Ensino, Ensino e Anos Escolares

# %%
df_regiao.groupby(['regiao','rede']).ideb.mean()
# Out:
# regiao        rede
# Centro-Oeste  estadual    4.200000
#               privada     6.100000
#               publica     4.581250
#               total       4.429167
# Nordeste      estadual    3.454167
#               privada     5.662500
#               publica     3.718750
#               total       3.754167
# Norte         estadual    3.745833
#               privada     5.654167
#               publica     3.893750
#               total       3.720833
# Sudeste       estadual    4.504167
#               privada     6.266667
#               publica     4.850000
#               total       4.700000
# Sul           estadual    4.350000
#               privada     6.400000
#               publica     4.781250
#               total       4.633333
# Name: ideb, dtype: float64

# %% [markdown]
# Insights:
# * Em todas as regiões, as escolas de rede privada obtiveram o maior IDEB;
# * Em todas as regiões, as escolas de rede pública obtiveram maior IDEB quando comparadas as escolas de rede estadual;
# * Na região Norte, as escolas de rede total superaram as escolas de rede estadual, entretanto nas demais regiões as escolas de rede estadual tiveram maiores valores de IDEB.

# %%
df_regiao.groupby(['regiao','ensino']).ideb.mean()
# Out:
# regiao        ensino
# Centro-Oeste  fundamental    5.078125
#               medio          4.241667
# Nordeste      fundamental    4.289062
#               medio          3.912500
# Norte         fundamental    4.462500
#               medio          3.816667
# Sudeste       fundamental    5.365625
#               medio          4.395833
# Sul           fundamental    5.275000
#               medio          4.504167
# Name: ideb, dtype: float64

# %% [markdown]
# Insights:
# * Em todas as regiões, o ensino fundamental teve maior IDEB do que o ensino médio;
# * A região Sudeste apresentou o maior IDEB para o ensino fundamental, enquanto a região Sul teve o maior IDEB para o ensino médio;
# * A região Nordeste teve o menor IDEB para o ensino fundamental, enquanto a região Norte apresentou o menor IDEB para o ensino médio.

# %%
df_regiao.groupby(['regiao','anos_escolares']).ideb.mean()
# Out:
# regiao        anos_escolares
# Centro-Oeste  finais (6-9)      4.631250
#               iniciais (1-5)    5.525000
#               todos (1-4)       4.241667
# Nordeste      finais (6-9)      3.987500
#               iniciais (1-5)    4.590625
#               todos (1-4)       3.912500
# Norte         finais (6-9)      4.184375
#               iniciais (1-5)    4.740625
#               todos (1-4)       3.816667
# Sudeste       finais (6-9)      4.828125
#               iniciais (1-5)    5.903125
#               todos (1-4)       4.395833
# Sul           finais (6-9)      4.781250
#               iniciais (1-5)    5.768750
#               todos (1-4)       4.504167
# Name: ideb, dtype: float64

# %% [markdown]
# Insights:
# * O maior e menor IDEB correspondente aos anos escolares **iniciais (1-5)** foram referentes às regiões: Sudeste e Nordeste respectivamente;
# * O maior e menor IDEB correspondente aos anos escolares **todos (1-4)** foram referentes às regiões: Sul e Norte respectivamente;
# * O maior e menor IDEB correspondente aos anos escolares **finais (6-9)** foram referentes às regiões: Sudeste e Nordeste respectivamente.

# %%
df_regiao.groupby(['regiao','rede','ensino','anos_escolares']).ideb.mean()
# Out:
# regiao        rede      ensino       anos_escolares
# Centro-Oeste  estadual  fundamental  finais (6-9)      4.0625
#                                      iniciais (1-5)    5.1750
#                         medio        todos (1-4)       3.3625
#               privada   fundamental  finais (6-9)      5.9875
#                                      iniciais (1-5)    6.6375
#                         medio        todos (1-4)       5.6750
#               publica   fundamental  finais (6-9)      4.1125
#                                      iniciais (1-5)    5.0500
#               total     fundamental  finais (6-9)      4.3625
#                                      iniciais (1-5)    5.2375
#                         medio        todos (1-4)       3.6875
# Nordeste      estadual  fundamental  finais (6-9)      3.2750
#                                      iniciais (1-5)    4.0125
#                         medio        todos (1-4)       3.0750
# ...

# %% [markdown]
# Podemos chegar as seguintes conclusões:
# * Todas as redes (estadual, privada, pública, total) tiveram maior IDEB para os anos_escolares **iniciais (1-5)**;
# * A rede privada obteve os maiores valores de IDEB para todas as categorias;

# %%
df_brasil.head()
# Out:
#     ano       rede       ensino  anos_escolares  taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 0  2005   estadual  fundamental    finais (6-9)            76.3              0.763635                232.86                       226.60                     4.324370   3.3       NaN
# 1  2005   estadual  fundamental  iniciais (1-5)            85.5              0.863753                181.13                       172.19                     4.551878   3.9       NaN
# 2  2005   estadual        medio     todos (1-4)            70.5              0.747708                260.02                       248.69                     4.064599   3.0       NaN
# 3  2005  municipal  fundamental    finais (6-9)            73.2              0.740564                228.44                       222.53                     4.182879   3.1       NaN
# ...

# %%
df_regiao.head()
# Out:
#     ano        regiao      rede       ensino  anos_escolares  taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 0  2005  Centro-Oeste  estadual  fundamental    finais (6-9)            72.1              0.721828                233.50                       227.88                     4.356453   3.1       NaN
# 1  2005  Centro-Oeste  estadual  fundamental  iniciais (1-5)            83.0              0.837081                185.38                       172.13                     4.631618   3.9       NaN
# 2  2005  Centro-Oeste  estadual        medio     todos (1-4)            68.0              0.695138                261.23                       251.52                     4.123654   2.9       NaN
# 3  2005  Centro-Oeste   privada  fundamental    finais (6-9)            94.4              0.943491                283.57                       266.82                     5.840183   5.5       NaN
# ...

# %% [markdown]
# Comparar as diferenças (ensino médio / ensino fundamental) entre cada região.

# %%
# Obter percentual máximo da diferença entre o melhor IDEB e o pior IDEB para cada região
data = df_regiao.groupby(['regiao','rede','ensino']).ideb.mean().reset_index()
max_percentuais = []
lista_dict_regiao = []
for regiao in data.regiao.unique():
  for ensino in data.ensino.unique():
    df_aux = data[(data.regiao == regiao) & (data.ensino == ensino)]
    max_df1 = df_aux.ideb.max()
    df_aux['percentual'] = (max_df1 - df_aux.ideb)/max_df1
    max_percentual = df_aux.percentual.max()
    max_percentuais.append(max_percentual)
    lista_dict_regiao.append(regiao)
values_column1 = np.array(lista_dict_regiao).reshape((len(lista_dict_regiao),1))
values_column2 = np.array(max_percentuais).reshape((len(max_percentuais),1))
values = np.concatenate((values_column1,values_column2),axis=1)
pd.DataFrame((values),columns=['Região','percentual']).groupby('Região').percentual.max().sort_values(ascending=False)
# Out:
# Região
# Nordeste        0.42117647058823515
# Norte            0.4172661870503597
# Centro-Oeste     0.4074889867841411
# Sul              0.3779193205944797
# Sudeste         0.37061403508771923
# Name: percentual, dtype: object

# %%
# Função que auxilia na plotagem dos gráficos barplot
def plot_barplot(num_attributes):
    fig, ax = plt.subplots(int(len(num_attributes.regiao.unique())),1, figsize=(15,30),sharex=True)
    regioes = num_attributes.regiao.unique()
    indice = 0
    for j in range(len(ax)):
        titulo = regioes[indice]
        df = num_attributes[num_attributes.regiao == regioes[indice]]
        df = df.drop(columns='regiao')
        ax[j].tick_params(labelsize=12)
        ax[j].tick_params(labelsize=10)
        ax[j] = sns.barplot(data=df, ax=ax[j],x='ideb',hue='ensino',y='rede').set_title(titulo)
        indice += 1
    fig.suptitle('IDEB por Rede e Região', position=(.5,1), fontsize=20)
    fig.tight_layout(pad=5)
    return
# Boxplot
plot_barplot(data)

# %% [markdown]
# Insights:
# * Conforme esperado a partir das interpretações dos gráficos anteriores, os valores de IDEB para o ensino fundamental são maiores que para o ensino médio;
# * O nordeste é a região com maior diferença percentual entre o IDEB da rede privada para as demais redes.

# %% [markdown]
# ## Evolução do IDEB ao longo dos anos

# %%
data = df_brasil.groupby('ano').ideb.mean().reset_index()
sns.lineplot(data=data,x='ano',y='ideb').set_title('IDEB ao longo dos anos',size=20);

# %% [markdown]
# Insights:
# * Notamos claramente o crescimento do IDEB ao longo dos anos. Principalmente, entre os anos de 2005 a 2009 e 2013 a 2019. O período de crescimento mais lento ocorreu entre 2009 e 2013.

# %%
data = df_regiao.groupby(['ano','regiao']).ideb.mean().reset_index()
for regiao in data.regiao.unique():
  df = data[data.regiao == regiao]
  sns.lineplot(data=df,x='ano',y='ideb').set_title('IDEB por Região ao longo dos anos',size=20)
plt.legend(data.regiao.unique());

# %% [markdown]
# Insights:
# * As regiões Sudeste e Sul sempre possuíram os maiores valores de IDEB;
# * A região Centro-Oeste sempre ocupou o terceiro lugar e tem se aproximado das regiões com maiores valores de IDEB;
# * A região Norte ocupou o quarto lugar de 2005 a 2017 entretanto foi superada pela região Nordeste em 2019;
# * Pode-se notar claramente que os três primeiros lugares apresentaram IDEB muito próximos entre si e os dois últimos lugares também apresentaram IDEB bastante próximos entre si. Porém, deve-se mencionar a grande diferença de IDEB entre a região que ocupou o terceiro lugar e a região que ocupou o quarto lugar.

# %% [markdown]
# ## IDEB por Estados e Região

# %%
data_uf = df_uf.groupby('sigla_uf').ideb.mean().reset_index()

# %%
# Estados
df_uf.sigla_uf.unique()
# Out:
# array(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG',
#        'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR',
#        'RS', 'SC', 'SE', 'SP', 'TO'], dtype=object)

# %%
# Estados Nordeste 
data_uf['regiao'] = 'Nordeste'

# %%
# Estados Norte 
estados_norte = ['AC','AM','AP','PA','RO','RR','TO']
data_uf['regiao'][np.isin(data_uf.sigla_uf,estados_norte)] = 'Norte'

# %%
# Estados Centro-Oeste
estados_centro = ['DF','GO','MS','MT']
data_uf['regiao'][np.isin(data_uf.sigla_uf,estados_centro)] = 'Centro-Oeste'

# %%
# Estados Sudeste
estados_centro = ['ES','MG','RJ','SP']
data_uf['regiao'][np.isin(data_uf.sigla_uf,estados_centro)] = 'Sudeste'

# %%
# Estados Sul
estados_sul = ['PR','RS','SC']
data_uf['regiao'][np.isin(data_uf.sigla_uf,estados_sul)] = 'Sul'

# %%
def plot_top_uf_regiao(df):
    fig, ax = plt.subplots(int(len(df.regiao.unique())),1, figsize=(10,25),sharex=True)
    regioes = df.regiao.unique()
    indice = 0
    for j in range(len(ax)):
        titulo = regioes[indice]
        data = df[df.regiao == regioes[indice]]
        data = data.drop(columns='regiao')
        ax[j].tick_params(labelsize=12)
        ax[j].tick_params(labelsize=10)
        ax[j] = sns.barplot(data=data, ax=ax[j],x='ideb',y='sigla_uf',).set_title(titulo)
        indice += 1
    fig.suptitle('IDEB por Estado e Região', position=(.5,1), fontsize=20)
    fig.tight_layout(pad=5)
    return
# Boxplot
plot_top_uf_regiao(data_uf)

# %% [markdown]
# Insights:
# * Alagoas possuiu o menor IDEB do país;
# * Minas Gerais e São Paulo possuíram os maiores valores de IDEB do país;
# * No norte, o estado com maior e menor IDEB respectivamente foram: Acre e Pará;
# * No nordeste, o Ceará teve maior IDEB e Alagoas menor IDEB;
# * No centro-oeste, o Distrito Federal apresentou o melhor IDEB enquanto Mato Grosso teve o menor IDEB;
# * No sudeste, Minas Gerais e São Paulo apresentaram maior IDEB e o Rio de Janeiro teve o menor IDEB;
# * No sul, Santa Catarina apresentou maior IDEB e o Rio Grande do Sul teve menor IDEB.

# %% [markdown]
# # Considerações Finais
#
# Através dessa análise exploratória dos dados dentre as conclusões obtidas podemos destacar as seguintes:
# * Notamos o crescimento no IDEB ao longo dos anos, fato bastante positivo pro país;
# * Percebemos que historicamente o nordeste foi a região com menor IDEB, apresentando um sinal de melhora na avaliação de 2019 quando superou a região norte, porém ambas as regiões ainda estão bem distantes de alcançar o IDEB das regiões sudeste, sul e centro-oeste;
# * Alagoas e Minas Gerais foram os estados com menor e maior IDEB respectivamente;
# * Desde 2005 até 2019, as regiões sudeste e sul estiveram no topo do ranking de IDEB do país;
# * Os 3 estados com maior IDEB foram: Minas Gerais (sudeste), São Paulo (sudeste) e Santa Catarina (sul);
# * Vimos também que em todo o país o ensino fundamental, especialmente o correspondente aos anos iniciais (1-5), possuíram maior IDEB do que o ensino médio;
# * As escolas de rede privada tiveram maior desempenho no IDEB do que as escolas que utilizaram outra rede de ensino;
# * Em todo o país, as escolas de rede pública obtiveram maior IDEB quando comparadas as escolas de rede estadual;
# * Na região Norte, as escolas de rede total tiveram maior IDEB do que as escolas de rede estadual, entretanto nas demais regiões as escolas de rede estadual superaram as escolas de rede total.
